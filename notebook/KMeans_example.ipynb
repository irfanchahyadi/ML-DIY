# %%
import sys
sys.path.append('../code')
import numpy as np
from KMeans.KMeans import KMeans

# %%
d = np.array([[12, 39],[20, 36],[28, 30],[18, 52],[29, 54],[33, 46],[24, 55],[45, 59],[45, 63],[52, 70],[51, 66],[52, 63],[55, 58],[53, 23],[55, 14],[61,  8],[64, 19],[69,  7],[72, 24],[20, 50]])

# %%
kmeans = KMeans(seed=100)
kmeans.fit(d, 3)
kmeans.report()

# %%
kmeans.predict(np.array([[10, 40], [40, 10]]))
# Out:
# array([0, 2], dtype=int64)

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=100, n_features=2, centers=4, cluster_std=0.7, random_state=100)
kmeans = KMeans(seed=100)
kmeans.fit(X, 5)
kmeans.report()
